# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 4</b>
#
#
# Thank you for the updates! My new comments have digit 4.  However, there are no issues that need to be fixed.
#
#
#
#
# Your project has passed code review. Congratulations 🎉
#
#
#
# This is a good [article](https://www.kaggle.com/ramprakasism/pandas-75-exercises-with-solutions/notebook) with 75 pandas exercises and solutions. You can go along the exercises and compare your solution with the solution in the article.
#
#
#
# Good luck! 😊
#
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 3</b>
#
#
# Thank you for the updates! My new comments have digit 3. There're just a couple of tiny but still important issues. Would you take a look? If anything seems difficult, please feel free to ask questions. I am here to help :)
#
#
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 2</b>
#
#
# Thank you for sending a new version of the project 😊 I've left a few comments titled as **Reviewer's comment 2**. Please take a look :)
#
#
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment</b>
#
# Hi William, I am a reviewer on this project. Glad to see you here!
#
#
# Before we start, I want to pay your attention to the color marking:
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
# Great solutions and ideas that can and should be used in the future are in green comments.
# </div>
#
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ⚠️</b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project.
# </div>
#
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌ </b>
#
# Issues that must be corrected to achieve accurate results are indicated in red comments. Please note that the project cannot be accepted until these issues are resolved.
#
# </div>
#
# <hr>
#
# **Please, use some color other than those listed to highlight answers to my comments.**
# I would also ask you **not to change, move or delete my comments** to make it easier for me to navigate during the next review.
#
# In addition, my comments are defined as headings.
# They can mess up the content; however, they are convenient, since you can immediately go to them. I will remove the headings from my comments in the next review if you ask me to.
#
#
# <hr>
#
# <font color='dodgerblue'>**A few words about the project:**</font> you did a good job, everything is clear and neat. The project is easy to read, which is definitely a plus. There are a lot graphs. It is good, visualization never hurts. I still have some questions that I've written in my comments. For instance,
#
#
# - Please make sure each cell works correctly before you send a project for review.
#
#
#
# - Please do not forget to add a conclusion to each task in sections A, B, and C.
#
#
# - Don't forget about the overall conclusion as well: what has been done and what can be inferred from the results (average order size, something about time and so on).
#
#
#
# I've also left there some recommendations for improving the project.  I will wait for the project for the second review :)
#
#
# <hr>
#
# Please feel free to schedule a 1:1 with our tutors or TAs, join daily coworking sessions, or ask questions in the sprint channels on Discord if you need assistance.
#
#
# <hr>
# 📌 Here are some hints that may help you with Markdown cells:
# <hr style="border-top: 3px solid purple; "></hr>
#
# You can leave comments using this code inside a Markdown cell:
#
#
#     <div class="alert alert-info">
#     <h2> Student's comment</h2>
#
#     Your text here.
#     </div>
#
#
#
#     <font color='red'> This code is used to change text color. </font>
#
# <font color='red'> It will look like this. </font>
#
# If you don't want your comments to be headings, replace **h2** with **b** or just add `<a class="tocSkip">` after the phrase *Student's comment*.
#
#
# You can find out how to **format text** in a Markdown cell or how to **add links** [here](https://sqlbak.com/blog/jupyter-notebook-markdown-cheatsheet).
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Instacart orders assessment</b>
#
# Reading out multiple data frames associated with Instacart orders to find missing values, filter out any duplicated information and gain a better understanding of what products are the most popular.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment ❌</b>
#
# First things first. The introduction is the initial paragraph that each project, each essay or any article should have. It is important to write an introductory part, because it gives an idea about the content of the project.
#
#
# Please add a title and project description.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 ❌</b>
#
# Would you please add a title to the project and an introduction that will tell a reader what the project is about?
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 ✔️</h2>
#
# Looks good!
# </div>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

df = pd.read_csv('/datasets/instacart_orders.csv', sep=';')
df
#reading in the data files
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0        1515936   183418            11          6                 13
# 1        1690866   163593             5          5                 12
# 2        1454967    39980             4          5                 19
# 3        1768857    82516            56          0                 20
# 4        3007858   196724             2          4                 12
# ...          ...      ...           ...        ...                ...
# 478962   3210681     5617             5          1                 14
# 478963   3270802   112087             2          3                 13
# 478964    885349    82944            16          2                 11
# 478965    216274     4391             3          3                  8
# 478966   2071924     1730            18          1                 14
#
#         days_since_prior_order
# 0                         30.0
# 1                          9.0
# ...

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>  Reviewer's comment ⚠️</h2>
#
#
# You can read data in one cell and put imports in another.
#
#
# </div>

# %%
df_products = pd.read_csv('/datasets/products.csv', sep=';')
df_products.info(show_counts=True)
df_products.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# ...

# %%
df_aisles = pd.read_csv('/datasets/aisles.csv',sep=';')
df_aisles
# Out:
#      aisle_id                       aisle
# 0           1       prepared soups salads
# 1           2           specialty cheeses
# 2           3         energy granola bars
# 3           4               instant foods
# 4           5  marinades meat preparation
# ..        ...                         ...
# 129       130    hot cereal pancake mixes
# 130       131                   dry pasta
# 131       132                      beauty
# 132       133  muscles joints pain relief
# 133       134  specialty wines champagnes
#
# [134 rows x 2 columns]

# %%
df_departments = pd.read_csv('/datasets/departments.csv',sep=';')
df_departments
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing

# %%
df_orderd_products = pd.read_csv('/datasets/order_products.csv',sep=';')
df_orderd_products.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440               17.0          0
# 1    567889        1560                1.0          1
# 2   2261212       26683                1.0          1
# 3    491251        8670               35.0          1
# 4   2571142        1940                5.0          1

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment ✔️</h2>
#
# The data was successfully read, good.
#
# </div>

# %% [markdown]
# ## Find and remove duplicate values (and describe why you make your choices)

# %% [markdown]
# ### `orders` data frame

# %%
# Check for duplicated orders
print(df.duplicated().sum())
# Out:
# 15

# %%
# Filter rows where order_dow == 2
filtered_df = df[df['order_dow'] == 2]

# Group by order_hour_of_day and count occurrences
grouped = filtered_df[filtered_df['order_hour_of_day'] == 2].count()

# Display the result

print(grouped['order_hour_of_day'])
# Out:
# 136

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Please try to print rows with the orders placed on Wednesday at 2:00 AM.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 ❌</b>
#
# There's no condition for days of week. </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 ✔️</h2>
#
# Now it's correct!
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>  Reviewer's comment 3 ⚠️</h2>
#
#
#
# Keep it simple:
# </div>

# %%
# Reviewer's code 3

df[(df['order_dow'] == 2) & (df['order_hour_of_day'] == 2)]
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 1295     1474941   115569             5          2                  2
# 2391     1640269   173965            15          2                  2
# 2550     1223696    55276            11          2                  2
# 5965      579194    85018            14          2                  2
# 17680    2004230   203121             4          2                  2
# ...          ...      ...           ...        ...                ...
# 457660   1562381    19378             5          2                  2
# 460316   1986084   117453            81          2                  2
# 462676   1362113    19654            20          2                  2
# 472800   1746383    88484            19          2                  2
# 472923   1519815   149345             1          2                  2
#
#         days_since_prior_order
# 1295                      28.0
# 2391                       2.0
# ...

# %%
# Remove duplicate orders
#duplicates = df[df.duplicated()] to pull the duplicated rows.reset_index()
duplicates = df.drop_duplicates(inplace=True)
print(duplicates)
# Out:
# None

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>  Reviewer's comment ⚠️</h2>
#
#
#
# - It is better to reset indices and drop the old ones.
#
#
#
# - Try to use **display** instead of **print** for the dataframes :) Display is a great thing. However, jupyter notebook is an interactive environment that already includes display. When we call a dataframe (see the code below), jupyter prints this dataframe like we do with the display method:
#
# </div>

# %%
# Reviewer's code

display(df.head(3))

df.tail(3)
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
#
#    days_since_prior_order
# 0                    30.0
# 1                     9.0
# 2                     2.0
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 478964    885349    82944            16          2                 11
# 478965    216274     4391             3          3                  8
# 478966   2071924     1730            18          1                 14
#
#         days_since_prior_order
# 478964                     6.0
# 478965                     8.0
# 478966                    15.0

# %%
# Double check for duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
# Double check for duplicate order IDs only
df['order_id'].nunique()
# Out:
# 478952

# %% [markdown]
# ### `products` data frame

# %%
# Check for fully duplicate rows
duplicates = df_products.duplicated()
duplicates.sum()
# Out:
# 0

# %%
# Check for just duplicate product IDs
duplicates = df_products.duplicated(subset='product_id')
print(duplicates.sum())
print()
print(df_products.head())
# Out:
# 0
#
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
#
# There are no duplicates here, good.
# </div>

# %%
# Check for just duplicate product names (convert names to lowercase to compare better)
df_products['product_name_lower'] = df_products['product_name'].str.lower()

df_products['product_name_lower'].duplicated().sum()
#product_name_lower shows a total of 1361 duplicated names
# Out:
# 1361

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# So how many duplicates do we have here?
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 ❌</b>
#
# What if we have millions of rows? Loops are very slow. Please try to apply the duplicated method.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 ✔️</h2>
#
#
# Correct.
#
# </div>

# %%
df_products
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49689       49690                      HIGH PERFORMANCE ENERGY DRINK
# 49690       49691                      ORIGINAL PANCAKE & WAFFLE MIX
# 49691       49692    ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 49692       49693                             SPRING WATER BODY WASH
# 49693       49694                            BURRITO- STEAK & CHEESE
#
#        aisle_id  department_id  \
# 0            61             19
# 1           104             13
# 2            94              7
# ...

# %%
# Step 1: Filter product names that are missing
valid_products = df_products[~df_products['product_name_lower'].isna()]

# Step 2: Convert product names to lowercase
valid_products['product_name_lower'] = valid_products['product_name'].str.lower()


duplicated_products= valid_products[valid_products.duplicated(['product_name_lower'])]
duplicated_products
# Out:
# /tmp/ipykernel_56/1439881742.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_products['product_name_lower'] = valid_products['product_name'].str.lower()
#        product_id                                     product_name  aisle_id  \
# 2058         2059                                  Biotin 1000 Mcg        47
# 5455         5456                 Green Tea With Ginseng and Honey        96
# 5558         5559                           Cream Of Mushroom Soup        69
# 7558         7559                        Cinnamon Rolls with Icing       105
# 9037         9038                           American Cheese slices        21
# ...           ...                                              ...       ...
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 4 ✔️</h2>
#
#
# Correct!
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3  ❌</b>
#
# We have to check for the duplicated names, not rows.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  2 ❌</b>
#
# Please try to use `isna` method here to take product names that are not missing. Then apply `str.lower()` and find duplicates.
#
#
#
# Do not forget about the conclusion please. What can you say about these duplicates?
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
#
# Correct.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# What can you say about these duplicates?
#
# </div>
#
# </div>
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Student's comment </b>
#
# I dont understand what you mean here, can you please elaborate?
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 4 ✔️</h2>
#
#
# For instance, we can notice that they have different `product_id`, so I am not sure whether we should treat them as duplicates. It's a good habit to always analyze the result :)
#
# </div>

# %% [markdown]
# It would appear that our duplicated products are from inconsistent spelling in the original column 'product_id', when column added with the lower case spelling we are able to identify the duplicated items.

# %% [markdown]
# ### `departments` data frame

# %%
print(df_departments.duplicated().sum())
# Out:
# 0

# %%
print(df_departments.isna().sum())
# Out:
# department_id    0
# department       0
# dtype: int64

# %% [markdown]
# ### `aisles` data frame

# %%
print(df_aisles.duplicated().sum())
# Out:
# 0

# %%
print(df_aisles.isna().sum())
# Out:
# aisle_id    0
# aisle       0
# dtype: int64

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment ✔️</h2>
#
# Correct.
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Check for fullly duplicate rows
print(df_orderd_products.duplicated().sum())
# Out:
# 0

# %%
# Double check for any other tricky duplicates
display(df_orderd_products.duplicated(subset=['order_id', 'product_id']).sum())
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 ✔️</h2>
#
# Well done! You can also take two columns and then apply the `duplicated` method.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Are there any `'order_id'` - `'product_id'` duplicates?
#
#
#
# Imagine you are looking for the duplicates in the dataframe:
#
# ```python
#
# John Smith 35
#
# John Smith 8
#
# John Adams 21
# ```
#
#
# There are three columns: first name, last name, and age. If we apply `duplicated` to this dataframe, we will not find any duplicates, since at least one of the values differs. However, if we try to find `'first name' - 'last name'` duplicates, we will notice that there are two people with the same full name, John Smith.
#
#
# Apply the same logic and try to look for the `'order_id'` - `'product_id'` duplicates. The `subset` parameter should help you. As a subset, use the list of columns: `subset=['order_id', 'product_id']`.</div>

# %% [markdown]
# ## Find and remove missing values

# %% [markdown]
# ### `products` data frame

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ⚠️</h2>
#
# Are there any missing values? The section is called "Find and remove missing values" :) So we have to at least find them.
#
# </div>

# %%
product_missing_values = df_products[df_products['product_name'].isna()]
product_missing_values
# Out:
#        product_id product_name  aisle_id  department_id product_name_lower
# 37             38          NaN       100             21                NaN
# 71             72          NaN       100             21                NaN
# 109           110          NaN       100             21                NaN
# 296           297          NaN       100             21                NaN
# 416           417          NaN       100             21                NaN
# ...           ...          ...       ...            ...                ...
# 49552       49553          NaN       100             21                NaN
# 49574       49575          NaN       100             21                NaN
# 49640       49641          NaN       100             21                NaN
# 49663       49664          NaN       100             21                NaN
# 49668       49669          NaN       100             21                NaN
#
# [1258 rows x 5 columns]

# %% [markdown]
# It appears as all missing values in the product name are associated with the same aisle and department.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 ⚠️</h2>
#
# > Without re-reading the data again the data frame does not show any missing data from what I can find
#
#
# Isn't it because you are looking for the missing values in a specific column?
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  2 ❌</b>
#
# Please do not read the data again.
# </div>

# %%
# Are all of the missing product names associated with aisle ID 100?
product_missing_values['aisle_id'].unique()
# Out:
# array([100])

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  2 ❌</b>
#
# The cell above does not work. Please be careful with the variables.
# </div>

# %%
# Are all of the missing product names associated with department ID 21?
product_missing_values['department_id'].unique()
# Out:
# array([21])

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 ⚠️</h2>
#
# So, yes, all of the missing product names are associated with department ID 21. Please, add clear conclusions and answers to the questions.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Does it answer the questions? We have to check whether all missing **product names** are associated with the specific aisle and department numbers.
# </div>

# %%
# What is this ailse and department?
display(df_aisles[df_aisles['aisle_id'].isin([100])])
display(df_departments[df_departments['department_id'].isin([21])])
# Out:
#     aisle_id    aisle
# 99       100  missing
#     department_id department
# 20             21    missing

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
#
# > What is this ailse and department?
#
# Try to print department from `departments` dataframe where department_id is 21 and aisle from `aisles` dataframes where aisle_id is 100. That's what they ask us about.
#
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Yes, each missing product name has `'missing'` label.
# </div>

# %%
# Fill missing product names with 'Unknown'
df_products['product_name'] = df_products['product_name'].fillna('Unknown')

# %% [markdown]
# We have successfully changed all the product names to "Unknown" and applied them to the data frame to make the data a little more readable for the user. As we can see the missing data was associated with the missing aisle and department.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
# Yes, we should replace them with some unique value, as it's hard to figure out a safer replacement.
# </div>

# %% [markdown]
# ### `orders` data frame

# %%
df.sort_values(by='user_id')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478952 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478952 non-null  int64
#  1   user_id                 478952 non-null  int64
#  2   order_number            478952 non-null  int64
#  3   order_dow               478952 non-null  int64
#  4   order_hour_of_day       478952 non-null  int64
#  5   days_since_prior_order  450135 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 25.6 MB

# %%
# Are there any missing values where it's not a customer's first order?
no_prior_orders = df[df['days_since_prior_order'].isna()]

print('Data frame with new orders:')
print(len(no_prior_orders))
print()
temp_df = no_prior_orders.drop('days_since_prior_order', axis=1)

# Find all rows with at least one missing value
missing_data = temp_df[temp_df.isnull().any(axis=1)]

print('Data frame with columns missing data:')
print(missing_data)
# Out:
# Data frame with new orders:
# 28817
#
# Data frame with columns missing data:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day]
# Index: []

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Would you show that?
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Yes, the dataframe is empty. </div>

# %% [markdown]
# ### `order_products` data frame

# %%
df_orderd_products.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %%
# What are the min and max values in this column?
print(df_orderd_products['add_to_cart_order'].min())
print(df_orderd_products['add_to_cart_order'].max())
# Out:
# 1.0
# 64.0

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# We are asked about min and max values in the column that has missing values. What min and max values does it have?
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Correct! </div>

# %%
# Save all order IDs with at least one missing value in 'add_to_cart_order'
miss_cart_order_ids=list(df_orderd_products[df_orderd_products['add_to_cart_order'].isna()]['order_id'].unique())
print(miss_cart_order_ids)
# Out:
# [2449164, 1968313, 2926893, 1717990, 1959075, 844733, 61355, 936852, 264710, 1564093, 129627, 293169, 2849370, 1386261, 3308010, 903110, 2136777, 3347453, 1888628, 165801, 2094761, 1038146, 2997021, 813364, 2256933, 171934, 2409109, 1730767, 1169835, 733526, 404157, 3125735, 747668, 1800005, 1961723, 871281, 388234, 1648217, 1477139, 102236, 1021563, 1832957, 2721963, 678116, 1220886, 1673227, 2999801, 1633337, 2470674, 2625444, 1677118, 2479011, 3383594, 1183255, 1713430, 2652650, 1598369, 1916118, 854647, 1302315, 888470, 180546, 2621907, 1308785, 2729254, 9310, 2170451, 2979697, 1625713, 1529171]

# %%
# Do all orders with missing values have more than 64 products?
min_value = df_orderd_products[df_orderd_products['order_id'].isin(miss_cart_order_ids)].groupby('order_id').size().sort_values()
min_value.min()
#As we can see all orders range from >65
# Out:
# 65

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# So, do all orders with missing values have more than 64 products?
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Exactly!
# </div>

# %%
# Replace missing values with 999 and convert column to integer type
df_orderd_products['order_id'] = df_orderd_products['order_id'].fillna(999).astype(int)

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ⚠️</h2>
#
# - `astype` can be applied right after `fillna`.
#
#
# - '999' is a string, not integer.
#
#
# - It will be great if you add a conclusion about the whole data preprocessing part here.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# The code looks better!
# </div>

# %% [markdown]
# # [A] Easy (must complete all to pass)

# %% [markdown]
# ### [A1] Verify that the `'order_hour_of_day'` and `'order_dow'` values in the `orders` tables are sensible (i.e. `'order_hour_of_day'` ranges from 0 to 23 and `'order_dow'` ranges from 0 to 6)

# %%
print(df['order_hour_of_day'].unique())
#unique values show 24 different hours ranging from 0-23 indicating a full day
# Out:
# [13 12 19 20 11  8 18 15 16  9 22 10  0 14 17  1  7  6  2 21  3 23  5  4]

# %%
print(df['order_dow'].unique())
#unique values show 7 different days ranging from 0 - 6 indicating a full week
# Out:
# [6 5 0 4 3 1 2]

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# For each task that you have done in sections A, B and C, write a conclusion please.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ⚠️</h2>
#
#
# It will be great if you use Markdown cells for your conclusions.
# </div>

# %% [markdown]
# ### [A2] What time of day do people shop for groceries?

# %%
order_counts_by_hour = df['order_hour_of_day'].value_counts().sort_index().plot(kind='bar')
plt.title('Orders by Time of day')
plt.xlabel('Time of day (hour)')
plt.ylabel('Orders')
# Out:
# Text(0, 0.5, 'Orders')

# %% [markdown]
# Peak hours range from 8 am to 6 pm, should increase staffing during peak hours to be able to handle the influx of customers

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Nice chart 👍
# </div>
#
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 ❌</b>
#
#
# What can be inferred from it?
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 ✔️</h2>
#
#
# So most orders occur between 9 AM and 5 PM.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# - Here and further we also need conclusion because it may be hard to a reader to figure out what's going on.
#
#
#
# - Let's add a chart here. Don't forget to add titles and axes labels so that a reader can easily understand what's going on here. It is also a good habit to leave some comments under each graph. We do our job for a client, and he or she may not understand the graph at all. That's why we need titels, labels and comments :)
#
#
# You can use the following piece of code:
# </div>
#
# ```python
#
# plt.title('Title')
# plt.xlabel('X')
# plt.ylabel('Y')
#
# ```

# %% [markdown]
# ### [A3] What day of the week do people shop for groceries?

# %%
order_counts_by_day = df['order_dow'].value_counts().sort_index().plot(kind='bar')
plt.title('Days people shop')
plt.xlabel('Day of the week')
plt.ylabel('Orders')
# Out:
# Text(0, 0.5, 'Orders')

# %% [markdown]
# most orders happen on days 0-1, cant make conclusion on the exact day of week it wouuld be as we have no way to identify specifically from previous data frame but could be concluded that 0-1 indicate Monday/Tuesday with 2-6 being Tuesday-Sunday.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Same issue. Would you add a chart and a conclusion?
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  2 ❌</b>
#
# Here and in each further task, please add a conclusion.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  3 ❌</b>
#
# > could be concluded that 0-1 indicate Satuday/Sunday with 2-6 being weekdays
#
#
# In the previous part, you used 2 to refer to Wednesday.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 4 ✔️</h2>
#
#
# Now it's correct!
# </div>

# %% [markdown]
# ### [A4] How long do people wait until placing another order?

# %%
#print(df.info())
order_counts_by_reordered = df['days_since_prior_order'].value_counts().sort_index().plot(kind='bar')
plt.title('Days till next order')
plt.xlabel('Days')
plt.ylabel('Orders')
#most orders made after 30 day or within the first week
# Out:
# Text(0, 0.5, 'Orders')

# %% [markdown]
# Based on the data assessed here we can conclude that most customers place orders once a month or within the first week after the original order was placed.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 4 ✔️</h2>
#
#
# Good! Some people may make an order once a month.
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 4  ⚠️</h2>
#
# Days can be integers :) Try to use `'Int64'` datatype that can handle Nans.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 ❌</b>
#
# Would you add a conclusion?
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Same issue.
#
# </div>

# %% [markdown]
# # [B] Medium (must complete all to pass)

# %% [markdown]
# ### [B1] Is there a difference in `'order_hour_of_day'` distributions on Wednesdays and Saturdays? Plot the histograms for both days and describe the differences that you see.

# %%
df_wed = df[(df['order_dow'] == 2)]
df_sat = df[(df['order_dow'] == 5)]

# write your code here
df_wed['order_hour_of_day'].plot(kind='hist', bins=24, ylabel='Orders', xlabel='Time of day (hour)', title= 'Order times / day')
df_sat['order_hour_of_day'].plot(kind='hist', bins=24, alpha=0.3)
plt.legend(['Wednesday','Saturday'])
plt.xlabel('Time of day (hour)')
plt.ylabel('Orders')
plt.show()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
#
# Very good.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>  Reviewer's comment ⚠️</h2>
#
#
# - Both axes should have a label.
#
#
# - Labels such as `Count` or `Frequency` may seem unclear to a reader. Try to add lucid labels and titles.
#
# </div>

# %%
df_wed['order_hour_of_day'].plot(kind='hist', bins=24, title= 'Order times / day', ylabel= 'Frequency' )
plt.show()

# %%
df_sat['order_hour_of_day'].plot(kind='hist', bins=20, title= 'Order times / day', ylabel= 'Frequency' )
plt.show()

# %%
#based on the information pulled here it appears that wed. has peak hours between 9 am and 5 pm
#sat has peak hours of 7 am and 3 pm with 3 pm doubling any other hour of the day

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
# Correct.
# </div>

# %% [markdown]
# ### [B2] What's the distribution for the number of orders per customer?

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
df = pd.read_csv('/datasets/instacart_orders.csv', sep=';')
df.groupby('user_id').order_id.count().value_counts().sort_index().plot(kind='bar')
plt.title('Customer orders by count')
plt.xlabel('Orders made')
plt.ylabel('Count by orders')
plt.show()

# %% [markdown]
# Chart would look as if most the customers and orders placed through Instacart are first time customers, however repeat busniess continues to diminish after each order made after that. If we were looking to focus on customer retention we could grow the business with a loyal customer base.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 ✔️</h2>
#
#
# Seems like most people usually have no more than 10 orders.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Very good chart! </div>
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  2 ❌</b>
#
# The cell above does not work, and there's no conclusion.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
#
# Without a chart, it's hard to make any inference here.
#
# </div>

# %% [markdown]
# ### [B3] What are the top 20 popular products (display their id and name)?

# %%
df_orderd_products.head(5)
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440               17.0          0
# 1    567889        1560                1.0          1
# 2   2261212       26683                1.0          1
# 3    491251        8670               35.0          1
# 4   2571142        1940                5.0          1

# %%
df_orderd_products.groupby('product_id').order_id.count().sort_values(ascending=False).head(20).plot(kind='bar')
plt.title('Customer orders by count')
plt.xlabel('Orders made')
plt.ylabel('Count by orders')
# Out:
# Text(0, 0.5, 'Count by orders')

# %%
merged_df = pd.merge(df_orderd_products, df_products[['product_id', 'product_name']], on='product_id', how='left')

merged_df.groupby('product_name').order_id.count().sort_values(ascending=False).head(20).plot(kind='bar')
                                                                                           
plt.title('Customer orders by count')
plt.xlabel('Orders made')
plt.ylabel('Count by orders')
# Out:
# Text(0, 0.5, 'Count by orders')

# %% [markdown]
# Based on the data we can see bananas are the most ordered items on Instacart. Organic items are ordered at a premium for all but 5 items in the list of top 20.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 4 ✔️</h2>
#
#
# Excellent!
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 ❌</b>
#
# - Would you add a conclusion?
#
#
#
# - We are also asked to display products' names.</div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Are these products the most popular? We also need to display their names. Try to merge `order_products` with `products`. Then apply the `count` method. Sort data by any column and choose any column (they are all going to be the same since we call count method) to represent the results.
#
#
# </div>

# %% [markdown]
# # [C] Hard (must complete at least two to pass)

# %% [markdown]
# ### [C1] How many items do people typically buy in one order? What does the distribution look like?

# %%
df_orderd_products.groupby(['order_id']).count().plot(kind='hist', bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Based on the data frame we can see that most orders contain on average 5-15 items. Largeer orders seem to be less frequent for Instacart orders with the largest orders containing no more than 50 items.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 ✔️</h2>
#
#
# Yes, a simple hist is a good solution here. It will be even better after you change **bins** value.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 ❌</b>
#
# Would you add a conclusion?
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 4 ✔️</h2>
#
#
# Well done!
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
#
#
# Let's make it simple.
#
#
# Group `order_products` dataframe by `order_id` and **count** values in some column. Then use `values_count` to find out the answer. But don't forget to sort indices to plot a graph properly.
#
# The length of the resulting dataframe or series should be equal to approximately 90 rows.
#
#
# </div>

# %% [markdown]
# ### [C2] What are the top 20 items that are reordered most frequently (display their names and product IDs)?

# %% [markdown]
# <div class="alert alert-info">
# <h2> Student's comment</h2>
#
# Top 20 items that are reordered.
#
# </div>
#
#
#
# <font color='red'> This code is used to change text color. </font>

# %%
# Step 1: Filter `order_products` where reorder = 1
reordered_products = df_orderd_products[df_orderd_products['reordered'] == 1]

# Step 2: Merge with `products` DataFrame on `product_id`
merged_data = pd.merge(reordered_products, df_products, on='product_id', how='inner')

# Step 3: Group by `product_id` and `product_name`, then count the occurrences
grouped_data = merged_data.groupby(['product_id', 'product_name']).size().reset_index(name='count')

# Step 4: Sort the results by count in descending order
sorted_data = grouped_data.sort_values(by='count', ascending=False).head(20)

# Display the results
sorted_data
# Out:
#        product_id              product_name  count
# 18104       24852                    Banana  55763
# 9528        13176    Bag of Organic Bananas  44450
# 15368       21137      Organic Strawberries  28639
# 15936       21903      Organic Baby Spinach  26233
# 34407       47209      Organic Hass Avocado  23629
# 34828       47766           Organic Avocado  18743
# 20285       27845        Organic Whole Milk  16251
# 34725       47626               Large Lemon  15044
# 20375       27966       Organic Raspberries  14748
# 12193       16797              Strawberries  13945
# 19088       26209                     Limes  13327
# 16700       22935      Organic Yellow Onion  11145
# 18186       24964            Organic Garlic  10411
# 32792       45007          Organic Zucchini  10076
# 36219       49683            Cucumber Kirby   9538
# 20543       28204        Organic Fuji Apple   8989
# 5978         8277  Apple Honeycrisp Organic   8836
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 4 ✔️</h2>
#
#
# Well done!
#
# </div>

# %% [markdown]
# As per the sorted data, we can see organic items have a higher reorder rate than the nonorganic counterparts with the exception of bananas, lime, strawberries and lemons.Based on this information we would need to ensure we have more inventory on the healthier options for these items.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 ❌</b>
#
#
# What does histogram represent?
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 ❌</b>
#
# Please don't forget to add the overall conclusion to your project: what has been done and what can be inferred from the results (average order size, something about time and so on).
#
# </div>

# %% [markdown]
# Student's general assessment
#
#
# All missing and duplicated data has been filtered out. After reviewing the mulitple data frames we can come to the conclusion that
# 1. Most of our customers shop only once with Instacart.
# 2. Peak hours of the day are fairly consistent with 9am-5pm.
# 3. Organic products are ordered more frequently than their nonorganic counterpart.
# 4. Average orders sizes are less than 20 items per order.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 4 ✔️</h2>
#
#
# Excellent job, thank you so much!
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
#
#
# Did this cell work? Don't forget to run the code before you send it for review.
#
# Please try to follow these steps:
#
#
# 1. Take products where **reorder** = 1 from `order_products` dataframe.
# 2. Merge with `products` on **product_id**.
# 3. Group by **product_id** and **product_name**
# 4. Count and sort.
#
#
#
# Do not forget to write a couple of sentences about the result.
# </div>

# %% [markdown]
# df_orderd_products.info()
#
# df_products.info()

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Please don't forget to add the overall conclusion to your project: what has been done and what can be inferred from the results (average order size, something about time and so on).
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 ❌</b>
#
# Would you add it?
# </div>

# %% [markdown]
# ### [C3] For each product, what proportion of its orders are reorders?

# %% [markdown]
# ### [C4] For each customer, what proportion of their products ordered are reorders?

# %% [markdown]
# ### [C5] What are the top 20 items that people put in their carts first?

# %%
Markdown and LaTeX:𝛼2
# Out:
#   Cell In[50], line 1
#     Markdown and LaTeX:𝛼2
#     ^
# SyntaxError: illegal target for annotation
