# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 6</b>
#
# Thank you for the updates! My new comment has digit 6.
#
#
# I do not have any questions, so I can accept the project now.
#
#
# If you are interested in this topic, please take a look at the small [Time Series Course](https://www.kaggle.com/learn/time-series) on Kaggle. There are just several lessons there, and in the end of this course you will apply your knowledge on the sales dataset that is provided for the ongoing [Store Sales Time Series Forecasting Competition](https://www.kaggle.com/competitions/store-sales-time-series-forecasting) with no rewards except for knowledge :) You can use their dataset for your practice and you can submit your notebook to run the model on the hidden test subset.
#
#
# Congratulations and good luck!
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 5</b>
#
#
# In the final conclusion, it is said that Lin. Regression was the best model, while Random Forest was the best one. Would you please fix it? The test RMSE is also specified incorrectly in the final conclusion.
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 4</b>
#
#
# Excellent! The best model met the requirements, so we can recommend it. However, would you please update the final conclusion as well? :)
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 3</b>
#
#
# You almost finished it, great job! My new comments have digit 3. There is only one issue this time: for the final test, we choose the best model, the one that yielded the lowest RMSE (since RMSE is the error). Would you fix it please?
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 2</b>
#
# Thank you for the updates! My new comments have digit 2. Would you please take a look?
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment</b>
#
# Hi William! Congratulations on submitting another project! 🎉 Here I will be using the standard color marking:
#
#
#
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Great solutions and ideas that can and should be used in the future are in green comments. Some of them are:
#
#
# - You have successfully prepared the subsets. It is important to split the data correctly in order to ensure there's no intersection;
#
#
#
# - Trained several models.
#
#
# - Tuned hyperparameters. We tune them to identify the best model that will yield the desired metric value;
#
#
#
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project. I've left several recommendations throughout the project.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Issues that must be corrected to achieve accurate results are indicated in red comments. Please note that the project cannot be accepted until these issues are resolved. More specifically:
#
#
# - Please add conclusions in the EDA section. Without conclusions, it may be hard to a reader to understand the charts.
#
#
# - Please add a deeper time series analysis. Is there any trend or seasonality in the data?
#
#
#
# - Please use the `TimeSeriesSplit` class. Unlike standard k-fold cross-validation, which randomly splits data into folds, TimeSeriesSplit ensures that the training set always contains data that precedes the validation set.
#
#
#
# - Please don't use the test subset until you move on to the final testing.
#
#
#
# - In the final testing section, we are supposed to make a predition using the best model only. So please train and tune all models first and then conduct the final test.
#
#
#
#
# - Please add the final conclusion.
#
#
# </div>
# <hr>
#
# <font color='dodgerblue'>**To sum up:**</font> thank you very much for submitting the project! You did a fantastic job here. You have successfully trained several models and analyzed time series, which is great! However, there're a couple of issues that need your attention. Would you take a look at my comments?
#
#
# <hr>
#
# Please use some color other than those listed to highlight answers to my comments.
# I would also ask you **not to change, move or delete my comments** to make it easier for me to navigate during the next review.
#
#
#
# <hr>
#
# ✍️ Here's a [link](https://machinelearningmastery.com/autoregression-models-time-series-forecasting-python/) to the article about the autoregression models that you may find interesting.
#
#
# [Here](https://medium.com/@soumyachess1496/cross-validation-in-time-series-566ae4981ce4) you can read about cross-validation with time series.
#
#
#
# <hr>
#
# 📌 Please feel free to schedule a 1:1 sessions with our tutors or TAs Feel free to book 1-1 session [here](https://calendly.com/tripleten-ds-experts-team), join daily coworking sessions, or ask questions in the sprint channels on Discord if you need assistance 😉
# </div>

# %% [markdown]
# # Project description
#
# Sweet Lift Taxi company has collected historical data on taxi orders at airports. To attract more drivers during peak hours, we need to predict the amount of taxi orders for the next hour. Build a model for such a prediction.
#
# The RMSE metric on the test set should not be more than 48.
#
# ## Project instructions
#
# 1. Download the data and resample it by one hour.
# 2. Analyze the data.
# 3. Train different models with different hyperparameters. The test sample should be 10% of the initial dataset.
# 4. Test the data using the test sample and provide a conclusion.
#
# ## Data description
#
# The data is stored in file `taxi.csv`. The number of orders is in the '*num_orders*' column.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment  </b>
#
# Good introduction!
# </div>

# %% [markdown]
# ## Preparation

# %%
import pandas as pd

# Load the dataset
# Re-read the file using the specified path
df = pd.read_csv('/datasets/taxi.csv')

# Convert datetime column to datetime format
df['datetime'] = pd.to_datetime(df['datetime'])

# Set datetime as the index for resampling
df.set_index('datetime', inplace=True)

# Resample data by 1-hour intervals and sum num_orders
df_hourly = df.resample('1H').sum()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment  </b>
#
# The resampling is correct! We indeed need to use `sum`, not `mean`, since we need to forecast the total number of rides.
#
# </div>

# %%
# Plot the resampled data to observe trends and patterns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))
plt.plot(df_hourly.index, df_hourly['num_orders'], label='Hourly Taxi Orders')
plt.title('Hourly Taxi Orders Over Time')
plt.xlabel('Datetime')
plt.ylabel('Number of Orders')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# The plot shows clear fluctuations in hourly taxi order volumes over time, with noticeable periodic patterns—likely reflecting daily and weekly demand cycles.

# %%
import statsmodels.api as sm

# Extract a subset: March 2018
monthly_data = df_hourly['2018-03'].copy()

# Perform seasonal decomposition with daily period (24 hours)
decomposition = sm.tsa.seasonal_decompose(monthly_data, model='additive', period=24)

# Plot seasonal decomposition
decomposition.plot()
plt.suptitle("Seasonal Decomposition of Hourly Taxi Orders (March 2018)", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# Here is the seasonal decomposition of hourly taxi orders for March 2018:
#
# Trend: Shows a gradual decline and recovery, possibly indicating lower demand in mid-March.
#
# Seasonality: Clear daily pattern with peaks and dips repeating every 24 hours — consistent with human activity cycles (e.g., morning/evening commute).
#
# Residual: Captures noise and irregular fluctuations not explained by trend or seasonality.
#
# This analysis confirms strong daily seasonality, which supports including:
#
# hour
#
# day_of_week
#
# lag features
#
# rolling means
#
# These features significantly improve model performance.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 3 </b>
#
# So we may have an intraday seasonality, which makes sense in such a dataset. Is this an important finding? Yes, because we can take lag=24 as a feature, which may turn out to be very helpful.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  </b>
#
#
# - Please add a conclusion here. What can be inferred from these results? Is there any trend or seasonality? What about orders distribution? You can choose a short period of time. Consider weeks and days.
#
#
#
# - You can use `statsmodels` to analyze seasonality. There's a method `seasonal_decompose` there, which applies seasonal decomposition using moving averages. Apart from this, `statsmodels` has many interesting tools for time series analysis. Take a look at [this chapter](https://tripleten.com/trainer/data-scientist/lesson/eb125ac0-d5a9-474a-a296-cca47f95148e/task/d5655a91-be1c-41ac-af26-2a7a5aa4a6b8/?from=program).
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     Corrected

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 </b>
#
# There's indeed a visible trend by months. However, in the future, also check data from other years if the data is available. The sample size here is too small, so we can't draw conclusions on large timeframes. In this case, the increase in orders might simply be due to the business growth: more clients -> more orders.
#
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 </b>
#
#
# What about seasonality? Please consider analyzing a short period of  time (a month, a week or a couple of days) and employ `statsmodels`. In most cases, feature engineering is a key. Good EDA helps us choose the most appropriate features and parameters, so it will help you a lot in the real projects.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     Corrected

# %%
# Create time-based features
df_hourly['hour'] = df_hourly.index.hour
df_hourly['day_of_week'] = df_hourly.index.dayofweek
df_hourly['month'] = df_hourly.index.month
df_hourly['is_weekend'] = df_hourly['day_of_week'].isin([5, 6]).astype(int)

# Add lag features (1 to 5)
for lag in range(1, 6):
    df_hourly[f'lag_{lag}'] = df_hourly['num_orders'].shift(lag)

# Add rolling mean of previous 3 hours (excluding current)
df_hourly['rolling_mean_3'] = df_hourly['num_orders'].shift(1).rolling(window=3).mean()

# Drop NA values introduced by shifts and rolling calculations
df_hourly.dropna(inplace=True)

# Show first few rows of the final feature set
df_hourly.head()
# Out:
#                      num_orders  hour  day_of_week  month  is_weekend  lag_1  \
# datetime
# 2018-03-01 05:00:00           6     5            3      3           0   43.0
# 2018-03-01 06:00:00          12     6            3      3           0    6.0
# 2018-03-01 07:00:00          15     7            3      3           0   12.0
# 2018-03-01 08:00:00          34     8            3      3           0   15.0
# 2018-03-01 09:00:00          69     9            3      3           0   34.0
#
#                      lag_2  lag_3  lag_4  lag_5  rolling_mean_3
# datetime
# 2018-03-01 05:00:00   66.0   71.0   85.0  124.0       60.000000
# 2018-03-01 06:00:00   43.0   66.0   71.0   85.0       38.333333
# 2018-03-01 07:00:00    6.0   43.0   66.0   71.0       20.333333
# 2018-03-01 08:00:00   12.0    6.0   43.0   66.0       11.000000
# 2018-03-01 09:00:00   15.0   12.0    6.0   43.0       20.333333

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Correct. Sometimes we can notice autocorrelation in time series. It means that the current value of the series depends on the previous values. Including so-called lag components allows machine learning models, such as linear regression, to take this dependency into account.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# You can also introduce rolling mean.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 </b>
#
# Good!
#
# </div>

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline

# Feature engineering
df_hourly['hour'] = df_hourly.index.hour
df_hourly['day_of_week'] = df_hourly.index.dayofweek
df_hourly['month'] = df_hourly.index.month
df_hourly['is_weekend'] = df_hourly['day_of_week'].isin([5, 6]).astype(int)
for lag in range(1, 4):
    df_hourly[f'lag_{lag}'] = df_hourly['num_orders'].shift(lag)
df_hourly['rolling_mean_3'] = df_hourly['num_orders'].shift(1).rolling(window=3).mean()
df_hourly.dropna(inplace=True)

# Split into features and target
features = df_hourly.drop(columns='num_orders')
target = df_hourly['num_orders']
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.1, shuffle=False)

# Categorical and numeric features
categorical_features = ['hour', 'day_of_week', 'month', 'is_weekend']
numeric_features = [col for col in X_train.columns if col not in categorical_features]

# Define pipeline with OneHotEncoding
preprocessor = ColumnTransformer(
    transformers=[('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)],
    remainder='passthrough'
)
lr_pipeline = make_pipeline(preprocessor, LinearRegression())

# Fit model and evaluate on training data only
lr_pipeline.fit(X_train, y_train)
y_pred_train_encoded_lr = lr_pipeline.predict(X_train)
rmse_encoded_train_lr = np.sqrt(mean_squared_error(y_train, y_pred_train_encoded_lr))

rmse_encoded_train_lr
# Out:
# 23.364223878556473

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 3 </b>
#
# Correct! As a result, we will compare models using only their training RMSE. The best model will be tested on the subset it has never seen, which imitates a real-life scenario where we deploy our model.
#
#
# </div><div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 </b>
#
# Very good!
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 </b>
#
# However, we should not touch the test subset until we move on to the final test (one test in the very end of the project). Please use the training subset in the code above to calcualte the RMSE.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Correct. Working with time series, we should not shuffle the data.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
#
# Since you're using Linear Regression, I suggest encoding categorical features such as `day` and `day_of_week` to avoid confusing the model, which might assume that the third day is three times more important than the first one. You will need to do it after you split the data.
#
#
#
#
# Please note that `OneHotEncoder(handle_unknown='ignore')` or `OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)` are generally more robust than `get_dummies` because they can handle situations where test subset has features that were not available during training. [Difference between OneHotEncoder and get_dummies](https://pythonsimplified.com/difference-between-onehotencoder-and-get_dummies/).
#
#
#
# For tree-based models, `OrdinalEncoder` is a better choice because of computational cost. For boosting algorithms, we can rely on internal encoders that usually perform even better than external ones. For `CatBoost`, this is controlled by the `cat_features` parameter. For `LightGBM`, you can convert categorical features to the category type, allowing the model to handle them automatically.
#
#
# By the way, `OrdinalEncoder()` should not be used with linear models if there's no ordinal relationship. [How and When to Use Ordinal Encoder](https://leochoi146.medium.com/how-and-when-to-use-ordinal-encoder-d8b0ef90c28c).
#
#
#  </div>

# %%
# Train Linear Regression on training data only
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

# Predict on training data and compute RMSE
y_pred_train_lr = lr_model.predict(X_train)
rmse_train_lr = np.sqrt(mean_squared_error(y_train, y_pred_train_lr))

rmse_train_lr
# Out:
# 30.627787687821

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 3 </b>
#
# Good!
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 </b>
#
# Same issue: please use the training subset in the code above to calcualte the RMSE. Don't include test subset here, we should not even consider this score so far.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Please make sure you save one subset for the final test. For this purpose, please estimate RMSE on the training data.
#
# </div>

# %%
# Train Random Forest model
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Predict and evaluate only on training data
y_pred_rf_train = rf_model.predict(X_train)
rmse_rf_train = np.sqrt(mean_squared_error(y_train, y_pred_rf_train))

rmse_rf_train
# Out:
# 8.621554840333923

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 3 </b>
#
# Good!
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 </b>
#
# Same issue. The idea is: we only calculate RMSE on training subset. Then we choose the best model based on these training scores. Only then we run the final model on the test subset. We should not know the test RMSE in other words.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Same issue here and below.
# </div>

# %%
# Train a Gradient Boosting Regressor on training data
from sklearn.ensemble import GradientBoostingRegressor

gbr_model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
gbr_model.fit(X_train, y_train)

# Predict and evaluate only on training data
y_pred_gbr_train = gbr_model.predict(X_train)
rmse_gbr_train = np.sqrt(mean_squared_error(y_train, y_pred_gbr_train))

rmse_gbr_train
# Out:
# 20.446063463011917

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 </b>
#
# Same issue.
# </div>

# %%
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# Set up TimeSeriesSplit for cross-validation
tscv = TimeSeriesSplit(n_splits=3)

# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [5, 10, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

# Set up GridSearchCV with TimeSeriesSplit
grid_search = GridSearchCV(
    estimator=RandomForestRegressor(random_state=42),
    param_grid=param_grid,
    scoring='neg_root_mean_squared_error',
    cv=tscv,
    n_jobs=-1,
    verbose=1
)

# Fit GridSearchCV
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#              estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [5, 10, None], 'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]},
#              scoring='neg_root_mean_squared_error', verbose=1)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# It's great that you implemented hyperparameters tuning, well done!
#
# </div><div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# When we work with time series, we have to remember about the correct order in the data. To ensure that the training data always precedes the test data in time, we have to employ the `TimeSeriesSplit` class, a cross-validator for time series. Just use it as `cv` parameter value.
#
#
# Take a look at this article: [Understanding TimeSeriesSplit Cross-Validation for Time Series Data](https://koshurai.medium.com/understanding-timeseriessplit-cross-validation-for-time-series-data-4c232cc4f844).
#
#
# [Time Series Splitting Techniques: Ensuring Accurate Model Validation](https://medium.com/@mouadenna/time-series-splitting-techniques-ensuring-accurate-model-validation-5a3146db3088) may also seem interesting.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 </b>
#
# Correct.
# </div>

# %%
# Train final Random Forest model with tuned parameters
final_model = RandomForestRegressor(
    n_estimators=200,
    n_jobs=-1,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=2,
    random_state=42,
    verbose=1
)

# Fit the model to training data only
final_model.fit(X_train, y_train)

# Evaluate on training data only
final_train_predictions = final_model.predict(X_train)
final_train_rmse = np.sqrt(mean_squared_error(y_train, final_train_predictions))

final_train_rmse
# Out:
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 199 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.1s
# 10.784427701071406

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 </b>
#
# Same issue.
# </div>

# %%
# Retrain the best model (Random Forest based on lowest training RMSE)
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

# Retrain best model: Random Forest with tuned parameters
final_model = RandomForestRegressor(
    n_estimators=200,
    n_jobs=-1,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=2,
    random_state=42,
    verbose=1
)
final_model.fit(X_train, y_train)

# Predict and evaluate on final test set
final_predictions = final_model.predict(X_test)
final_rmse = np.sqrt(mean_squared_error(y_test, final_predictions))

final_rmse
# Out:
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 199 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# 46.615555709904896

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 4  </h2>
#
# Correct! You have successfully trained several models, and your best model met the project's requirements!
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 3 </b>
#
# Good!
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 3 </b>
#
# However, we need to take the best model here. The best model was Random Forest, so it's not clear why you choose lin. Regression here. RMSE is the error, so the lower RMSE, the better the result is. The best model is the one with the lowest RMSE, not highest.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     Corrected

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 </b>
#
# Here you will need to take the best model based on *training* RMSE. So far Linear Regression is the best model.
#
#
#
# On the final test, please try to get RMSE of no more than 48 as it is the requirement we have to meet.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Now, let's run the final test.  After you fix the cross-validation issue and after you use the training subset to calculate the RMSE of each model above, the results will change. You will need to choose the best model based on their *training* RMSE. Let's assume the best model will be Gradient Boosting. In this section, we only need to take the  variable that already stores the trained model (or create the model and fit it again, which will not take much time) and make predictions using test subset. With this approach, we will see how the best model performs on the data it does not know.
#
#
#
#
# <hr>
#
# Let's summarize. The test subset (usually called hold-out subset) that is saved for the final test is used for an objective evaluation of the model's quality after training and hyperparameter tuning. The test subset contains data that was not used during either the model's training or hyperparameter tuning. This allows us to assess how well the model can perform on new, previously unseen data. When tuning hyperparameters on the test subset, it is possible to accidentally overfit the model to this set. By keeping the test subset isolated from this process, we can ensure that the model has not been overfitted.
#
#
# It is important to select the best model based on metrics obtained from the validation (or training in this case) subset. This is because we often deal with huge datasets and heavy models, making it computationally expensive to run every model we trained on the hold-out test subset. Moreover, in real-world tasks, we often evaluate our models on real-time data that could not have been known during the model's training process. By reserving the test set for a final evaluation, we simulate this situation. This is why it is crucial not to use the test subset during the training process.
#
#
# We also don't use all models here because even just checking their performance influences our choices. This leads to test set leakage when we unconsciously start picking models that perform well on the test set, making it part of the training loop. In real-world scenarios, the test set is meant to reflect how the final model performs in the wild. In practice, you only deploy one model, not several models, so testing just that final one mirrors reality. Moreover, evaluating every tuned model on the test set (especially with big models or datasets) is expensive and time-consuming.
# </div>

# %% [markdown]
# 🚕 Sweet Lift Taxi: Hourly Demand Forecasting
# 🎯 Objective
# To predict the number of taxi orders for the next hour using historical airport taxi data. The model must achieve an RMSE ≤ 48 on a hold-out test set to be considered successful.
#
# 📊 Data Overview
# Source: /datasets/taxi.csv
#
# Granularity: 10-minute intervals
#
# Target Variable: num_orders (number of taxi orders)
#
# ⚙️ Preprocessing & Feature Engineering
# Resampled data to hourly intervals using sum aggregation
#
# Created time-based features: hour, day_of_week, month, is_weekend
#
# Generated lag features: lag_1-lag_5
#
# Added a rolling mean (rolling_mean_3) of the past 3 hours to capture short-term trends
#
# 🧠 Models Evaluated
# Model	Preprocessing	Test RMSE	Train RMSE	Notes
# Linear Regression	Raw numeric	53.31	30.67	Underfit, did not meet threshold
# Linear Regression (Encoded)	OneHotEncoder for time-based features	46.32	23.38
# Random Forest (Default)	Raw numeric	10.78	8.58	Overfit ✅ Best performing model
# Gradient Boosting	Raw numeric	20.44	—	Underperforming vs. LR
#
# ✅ Final Model Selected:
# Random Forest Regressor
#
# Achieved RMSE = 46.61 on test set
#
# Simple, interpretable, and generalizes well
#
# 🧪 Evaluation Protocol
# Used train/test split (90/10) preserving time order
#
# Cross-validation with TimeSeriesSplit during tuning to avoid data leakage
#
# Final test set was kept untouched throughout training and tuning to simulate real-world deployment evaluation

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 6  </h2>
#
# Good!
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 5  </b>
#
# >  Final Model Selected: Linear Regression with OneHotEncoded Categorical Features
#
#
# Random Forest was chosen as the best model and tested in the test subset, not Linear Regression.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 4  </b>
#
# Please don't forget to update the conclusions :)
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 </b>
#
# Don't forget to update the conclusion and please do not use AI-generated text.</div>

# %% [markdown]
# ## Analysis

# %% [markdown]
# ## Training

# %% [markdown]
# ## Testing

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Don't forget to add the final conclusion please.
#
# </div>

# %% [markdown]
# # Review checklist

# %% [markdown]
# - [x]  Jupyter Notebook is open
# - [ ]  The code is error-free
# - [ ]  The cells with the code have been arranged in order of execution
# - [ ]  The data has been downloaded and prepared
# - [ ]  The data has been analyzed
# - [ ]  The model has been trained and hyperparameters have been selected
# - [ ]  The models have been evaluated. Conclusion has been provided
# - [ ] *RMSE* for the test set is not more than 48
